# %%
# %env OPENAI_API_KEY = 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
# %load_ext jupyter_ai_magics

import pandas as pd
import pandasai
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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")
# Out:
# env: OPENAI_API_KEY=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
# /Users/alexander/.virtualenvs/jupyter/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
